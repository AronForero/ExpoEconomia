# %% [markdown]
# ## Primer archivo de Inflacion

# %%
import pandas as pd
import bokeh.plotting as bp
import datetime
from bokeh.models import CustomJS, Slider
from bokeh.io import output_notebook, show

# %%
book1 = pd.read_csv('../Book1.csv', sep=';')
book1.head()
# Out:
#    Año_Mes Inflacion Limitesuperior Metadeinflacion Limiteinferior
# 0  2017-09      3,97           4,00            3,00           2,00
# 1  2017-08      3,87           4,00            3,00           2,00
# 2  2017-07      3,40           4,00            3,00           2,00
# 3  2017-06      3,99           4,00            3,00           2,00
# 4  2017-05      4,37           4,00            3,00           2,00

# %%
fecha = pd.to_datetime(book1.Año_Mes) #dejo todo como tipo fecha
y = [float(i.replace(",", ".")) for i in book1.Inflacion] #tiene , en vez de . cambio eso para convertir a float
sup = [float(str(i).replace(",",".")) for i in book1.Limitesuperior]
inf = [float(str(i).replace(",",".")) for i in book1.Limiteinferior]
rango = sup+inf

# %%
fecha_01 = [str(i)[:7] for i in fecha]

# %% [markdown]
#     -Notas 05b ML fillbetween
#     -arreglar los datos para poder generar un patch como rango sup/inf

# %%
fig = bp.figure(title="Inflacion a lo largo de los Años", x_axis_label="Año", y_axis_label="inflacion", x_range=fecha_01[-1::-1], plot_width=1000, plot_height=850)
figline = fig.line(fecha_01, y, line_width=2)
figline2 = fig.line(fecha_01, sup, alpha = 0.5, line_width=4, color = "green")
figline3 = fig.line(fecha_01, inf, alpha = 0.5, line_width=4, color = "red")
#figpatch = fig.patch(fecha, rango, alpha = 0.5, line_width=1, color = "green")

# %%
bp.output_file('graf.html')
show(fig)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="42652a53-5f04-4c9c-a2d0-02a909919801"></div>
# </div>

# %% [markdown]
# ### Segundo Archivo...

# %%
book2 = pd.read_csv('../Book2.csv', sep=';')
book2.head()
# Out:
#    AnioMes Sin_alimentos_primarios_servicios_publicos_y_combustibles_Indice  \
# 0  1982-03                                                NaN
# 1  1982-04                                                NaN
# 2  1982-05                                                NaN
# 3  1982-06                                                NaN
# 4  1982-07                                                NaN
#
#   Sin_alimentos_primarios_servicios_publicos_y_combustibles_Variacion_Anual  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sin_alimentos_ni_regulados_Indice  \
# 0                           2,53322
# 1                           2,58214
# 2                           2,63447
# 3                           2,66243
# 4                           2,71060
#
# ...

# %%
fecha2 = pd.to_datetime(book2.AnioMes, yearfirst = True) #dejo todo como tipo fecha
fecha_02 = [str(i) for i in fecha2]
y = [float(str(i).replace(",", ".")) for i in book2.Sin_alimentos_primarios_servicios_publicos_y_combustibles_Indice] #tiene , en vez de . cambio eso para convertir a float
#y2 = [float(str(i).replace(",", ".")) for i in book2.Sin_alimentos_primarios_servicios_publicos_y_combustibles_Variacion_Anual]
y3 = [float(i.replace(",", ".")) for i in book2.Sin_alimentos_ni_regulados_Indice]
#y4 = [float(str(i).replace(",", ".")) for i in book2.Sin_alimentos_ni_regulados_Variacion_Anual]
y5 = [float(str(i).replace(",", ".")) for i in book2.Sin_alimentos_Indice]
#y6 = [float(str(i).replace(",", ".")) for i in book2.Sin_alimentos_Variacion_Anual]
y7 = [float(str(i).replace(",", ".")) for i in book2.Ipc_nucleo_20_Indice]
#y8 = [float(str(i).replace(",", ".")) for i in book2.Ipc_nucleo_20_Variacion_Anual]

# %%
fig2 = bp.figure(title="Inflacion a lo largo de los Años", x_axis_label="Año", y_axis_label="inflacion", x_range=fecha_02)
figlin = fig2.line(fecha_02, y, line_width=2)
#figlin2 = 
figlin3 = fig2.line(fecha_02, y3, line_width=2, color="firebrick")
#figlin4 = 
figlin5 = fig2.line(fecha_02, y5, line_width=2, color="black")
#figlin6 = 
figlin7 = fig2.line(fecha_02, y7, line_width=2, color="yellow")
#figlin8 =

# %%
show(fig2)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1fe3908f-903a-4c28-9c28-d7144f26ea02"></div>
# </div>
